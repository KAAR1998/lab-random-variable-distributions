# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib as plt 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, mean_squared_error

# %%
#1. Get the numerical variables from our dataset.

# %%
df = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
df_num = df.select_dtypes(include = np.number)

# %%
df_num.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
sns.displot(df_num['Customer Lifetime Value'])
plt.show()

# %%
sns.displot(df_num['Income'])
plt.show()

# %%
sns.displot(df_num['Monthly Premium Auto'])
plt.show()

# %%
sns.displot(df_num['Months Since Last Claim'])
plt.show()

# %%
sns.displot(df_num['Months Since Policy Inception'])
plt.show()

# %%
sns.displot(df_num['Number of Open Complaints'])
plt.show()

# %%
sns.displot(df_num['Number of Policies'])
plt.show()

# %%
sns.displot(df_num['Total Claim Amount'])
plt.show()

# %%
#3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
np.log(df_num['Customer Lifetime Value'])
var_log = list(map(np.log, df_num['Customer Lifetime Value']))
sns.displot(var_log)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Income'])
var_log = list(map(np.log, df_num['Income']))
sns.displot(var_log)
plt.show
# Out:
# /Users/aloaskari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/zh/vb5lf3750v95681z25hzkm9c0000gn/T/ipykernel_21217/4215380397.py:2: RuntimeWarning: divide by zero encountered in log
#   var_log = list(map(np.log, df_num['Income']))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Monthly Premium Auto'])
var_log = list(map(np.log, df_num['Monthly Premium Auto']))
sns.displot(var_log)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Months Since Last Claim'])
var_log = list(map(np.log, df_num['Months Since Last Claim']))
sns.displot(var_log)
plt.show
# Out:
# /Users/aloaskari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/zh/vb5lf3750v95681z25hzkm9c0000gn/T/ipykernel_21217/1514364191.py:2: RuntimeWarning: divide by zero encountered in log
#   var_log = list(map(np.log, df_num['Months Since Last Claim']))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Months Since Policy Inception'])
var_log = list(map(np.log, df_num['Months Since Policy Inception']))
sns.displot(var_log)
plt.show
# Out:
# /Users/aloaskari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/zh/vb5lf3750v95681z25hzkm9c0000gn/T/ipykernel_21217/2198938783.py:2: RuntimeWarning: divide by zero encountered in log
#   var_log = list(map(np.log, df_num['Months Since Policy Inception']))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Number of Open Complaints'])
var_log = list(map(np.log, df_num['Number of Open Complaints']))
sns.displot(var_log)
plt.show
# Out:
# /Users/aloaskari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/zh/vb5lf3750v95681z25hzkm9c0000gn/T/ipykernel_21217/2342910991.py:2: RuntimeWarning: divide by zero encountered in log
#   var_log = list(map(np.log, df_num['Number of Open Complaints']))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.log(df_num['Number of Policies'])
var_log = list(map(np.log, df_num['Number of Policies']))
sns.displot(var_log)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import PowerTransformer 

pt = PowerTransformer()

df_num1 = df_num['Customer Lifetime Value'].array.reshape(-1, 1)

df_num1_transformed = pt.fit_transform(df_num1)

sns.displot(df_num1_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num2 = df_num['Income'].array.reshape(-1, 1)

df_num2_transformed = pt.fit_transform(df_num2)

sns.displot(df_num2_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num3 = df_num['Monthly Premium Auto'].array.reshape(-1, 1)

df_num3_transformed = pt.fit_transform(df_num3)

sns.displot(df_num3_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num4 = df_num['Months Since Last Claim'].array.reshape(-1, 1)

df_num4_transformed = pt.fit_transform(df_num4)

sns.displot(df_num4_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num5 = df_num['Months Since Policy Inception'].array.reshape(-1, 1)

df_num5_transformed = pt.fit_transform(df_num5)

sns.displot(df_num5_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num6 = df_num['Number of Open Complaints'].array.reshape(-1, 1)

df_num6_transformed = pt.fit_transform(df_num6)

sns.displot(df_num6_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num7 = df_num['Number of Policies'].array.reshape(-1, 1)

df_num7_transformed = pt.fit_transform(df_num7)

sns.displot(df_num7_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num8 = df_num['Total Claim Amount'].array.reshape(-1, 1)

df_num8_transformed = pt.fit_transform(df_num8)

sns.displot(df_num8_transformed)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
